# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# read data
top_dir = '/Users/stiso/Documents/Python/graphLearning/ECoG data/behavioral_data_raw/'
save_dir = '/Users/stiso/Documents/Python/graphLearning/ECoG data/behavior_preprocessed/'
subj = [1,2,4]

# %%
#%% Load and concatenate data

data = pd.DataFrame()
for i in subj:
    curr = pd.read_csv("".join([top_dir, 'subj', str(i), '/subj', str(i), '_clean_data']))
    curr['subj'] = i
    data = data.append(curr)
# Out:
# /Users/stiso/anaconda2/lib/python2.7/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
data
# Out:
#      ISI_raw  Unnamed: 0  correct_raw    graph   hand  hand_transition  lag10  \
# 0       0.05           5          1.0  lattice   left            False      1
# 1       0.05           8          1.0  lattice  right            False      1
# 2       0.05           9          1.0  lattice  right            False      1
# 3       0.05          12          1.0  lattice  right             True      0
# 4       0.05          13          1.0  lattice  right            False      2
# 5       0.05          14          1.0  lattice  right            False      2
# 6       0.05          15          1.0  lattice  right            False      3
# 7       0.05          16          1.0  lattice   left             True      1
# 8       0.05          17          1.0  lattice   left            False      1
# 9       0.05          18          1.0  lattice   left            False      0
# 10      0.05          20          1.0  lattice   left             True      1
# 11      0.05          22          1.0  lattice  right            False      0
# 12      0.05          23          1.0  lattice   left             True      0
# 13      0.05          24          1.0  lattice   left            False      0
# 14      0.05          25          1.0  lattice  right             True      1
# 15      0.05          26          1.0  lattice   left             True      1
# 16      0.05          27          1.0  lattice  right             True      0
# 17      0.05          29          1.0  lattice  right             True      0
# 18      0.05          30          1.0  lattice  right            False      1
# 19      0.05          31          1.0  lattice   left             True      2
# 20      0.05          32          1.0  lattice   left            False      1
# 21      0.05          33          1.0  lattice   left            False      3
# 22      0.05          35          1.0  lattice  right            False      2
# 23      0.05          37          1.0  lattice   left            False      0
# 24      0.05          38          1.0  lattice   left            False      0
# 25      0.05          40          1.0  lattice  right             True      0
# 26      0.05          41          1.0  lattice   left             True      1
# 27      0.05          42          1.0  lattice   left            False      1
# 28      0.05          43          1.0  lattice   left            False      1
# 29      0.05          45          1.0  lattice   left             True      0
# ..       ...         ...          ...      ...    ...              ...    ...
# 895     0.05         968          1.0  modular   left            False      1
# 896     0.05         969          1.0  modular  right             True      1
# 897     0.05         970          1.0  modular  right            False      1
# 898     0.05         971          1.0  modular   left             True      0
# 899     0.05         973          1.0  modular  right            False      1
# 900     0.05         974          1.0  modular  right            False      1
# 901     0.05         975          1.0  modular   left             True      0
# 902     0.05         976          1.0  modular  right             True      2
# 903     0.05         977          1.0  modular  right            False      1
# 904     0.05         978          1.0  modular   left             True      1
# 905     0.05         979          1.0  modular   left            False      1
# 906     0.05         980          1.0  modular  right             True      1
# 907     0.05         981          1.0  modular  right            False      2
# 908     0.05         982          1.0  modular   left             True      1
# 909     0.05         983          1.0  modular   left            False      2
# 910     0.05         984          1.0  modular   left            False      2
# 911     0.05         985          1.0  modular   left            False      3
# 912     0.05         986          1.0  modular   left            False      3
# 913     0.05         987          1.0  modular  right             True      0
# 914     0.05         988          1.0  modular  right            False      1
# 915     0.05         989          1.0  modular  right            False      1
# 916     0.05         990          1.0  modular   left             True      3
# 917     0.05         991          1.0  modular  right             True      2
# 918     0.05         992          1.0  modular   left             True      4
# 919     0.05         993          1.0  modular  right             True      0
# 920     0.05         994          1.0  modular   left             True      1
# 921     0.05         995          1.0  modular   left            False      3
# 922     0.05         996          1.0  modular  right             True      1
# 923     0.05         998          1.0  modular  right             True      1
# 924     0.05         999          1.0  modular   left             True      1
#
#       onset_raw     order  pID ...  recency  resp resp_raw    rt_raw  sess  \
# 0      7.087798  0.778151  1.0 ...      2.0     q    ['q']  0.945559   NaN
# 1     10.337893  0.954243  1.0 ...      2.0     b    ['b']  0.752210   NaN
# 2     11.187585  1.000000  1.0 ...      2.0     u    ['u']  0.581672   NaN
# 3     13.455660  1.113943  1.0 ...     11.0     p    ['p']  0.810152   NaN
# 4     14.357635  1.146128  1.0 ...      4.0     u    ['u']  1.003771   NaN
# 5     15.457186  1.176091  1.0 ...      6.0     b    ['b']  0.735995   NaN
# 6     16.288177  1.204120  1.0 ...      2.0     u    ['u']  0.808980   NaN
# 7     17.190220  1.230449  1.0 ...      5.0     e    ['e']  1.387098   NaN
# 8     18.674009  1.255273  1.0 ...      7.0     r    ['r']  0.799790   NaN
# 9     19.574129  1.278754  1.0 ...     14.0     v    ['v']  1.122980   NaN
# 10    23.305658  1.322219  1.0 ...      2.0     v    ['v']  0.743061   NaN
# 11    25.206577  1.361728  1.0 ...     22.0     i    ['i']  1.930772   NaN
# 12    27.222677  1.380211  1.0 ...     21.0     w    ['w']  1.035126   NaN
# 13    28.356907  1.397940  1.0 ...     19.0     q    ['q']  0.684742   NaN
# 14    29.140696  1.414973  1.0 ...      4.0     o    ['o']  1.316966   NaN
# 15    30.559404  1.431364  1.0 ...      3.0     w    ['w']  0.737794   NaN
# 16    31.390865  1.447158  1.0 ...     15.0     p    ['p']  1.482515   NaN
# 17    34.757835  1.477121  1.0 ...     14.0     u    ['u']  0.674657   NaN
# 18    35.524303  1.491362  1.0 ...      3.0     p    ['p']  0.700958   NaN
# 19    36.323383  1.505150  1.0 ...      5.0     w    ['w']  0.893154   NaN
# 20    37.306942  1.518514  1.0 ...      8.0     q    ['q']  1.173339   NaN
# 21    38.574467  1.531479  1.0 ...      2.0     w    ['w']  0.858868   NaN
# 22    41.374260  1.556303  1.0 ...      5.0     p    ['p']  0.801811   NaN
# 23    45.307747  1.579784  1.0 ...     20.0     r    ['r']  1.628939   NaN
# 24    47.025700  1.591065  1.0 ...     18.0     v    ['v']  1.414930   NaN
# 25    50.258545  1.612784  1.0 ...     21.0     b    ['b']  1.701352   NaN
# 26    52.058205  1.623249  1.0 ...      4.0     r    ['r']  0.861718   NaN
# 27    53.009296  1.633468  1.0 ...      4.0     v    ['v']  1.318455   NaN
# 28    54.427456  1.643453  1.0 ...      4.0     q    ['q']  1.261130   NaN
# 29    60.314476  1.662758  1.0 ...     12.0     w    ['w']  1.653943   NaN
# ..          ...       ...  ... ...      ...   ...      ...       ...   ...
# 895  703.028381  2.986324  4.0 ...      6.0     q    ['q']  0.482578   1.0
# 896  703.611877  2.986772  4.0 ...      8.0     i    ['i']  0.714059   1.0
# 897  704.411865  2.987219  4.0 ...     10.0     b    ['b']  0.474218   1.0
# 898  704.978638  2.987666  4.0 ...     12.0     r    ['r']  0.659230   1.0
# 899  706.661499  2.988559  4.0 ...      3.0     b    ['b']  0.615966   1.0
# 900  707.377502  2.989005  4.0 ...      2.0     p    ['p']  0.460079   1.0
# 901  707.928467  2.989450  4.0 ...     27.0     v    ['v']  0.486129   1.0
# 902  708.512268  2.989895  4.0 ...      3.0     b    ['b']  0.557227   1.0
# 903  709.162354  2.990339  4.0 ...      8.0     i    ['i']  0.507060   1.0
# 904  709.762329  2.990783  4.0 ...      3.0     v    ['v']  0.531281   1.0
# 905  710.378357  2.991226  4.0 ...      8.0     r    ['r']  0.411196   1.0
# 906  710.878723  2.991669  4.0 ...      3.0     i    ['i']  0.551197   1.0
# 907  711.528320  2.992111  4.0 ...      5.0     b    ['b']  0.486383   1.0
# 908  712.112183  2.992554  4.0 ...      3.0     r    ['r']  0.573462   1.0
# 909  712.782410  2.992995  4.0 ...      5.0     v    ['v']  0.479191   1.0
# 910  713.362671  2.993436  4.0 ...      2.0     r    ['r']  0.506885   1.0
# 911  713.962769  2.993877  4.0 ...      2.0     v    ['v']  0.642664   1.0
# 912  714.695740  2.994317  4.0 ...      2.0     r    ['r']  0.509597   1.0
# 913  715.296204  2.994757  4.0 ...     13.0     p    ['p']  0.533175   1.0
# 914  715.929565  2.995196  4.0 ...      7.0     b    ['b']  0.451696   1.0
# 915  716.478333  2.995635  4.0 ...      2.0     p    ['p']  0.504099   1.0
# 916  717.079773  2.996074  4.0 ...      4.0     r    ['r']  0.486569   1.0
# 917  717.663025  2.996512  4.0 ...      2.0     p    ['p']  0.526709   1.0
# 918  718.279602  2.996949  4.0 ...      2.0     r    ['r']  0.502848   1.0
# 919  718.879883  2.997386  4.0 ...     13.0     i    ['i']  0.534317   1.0
# 920  719.513245  2.997823  4.0 ...      9.0     v    ['v']  0.620820   1.0
# 921  720.229980  2.998259  4.0 ...      3.0     r    ['r']  0.448241   1.0
# 922  720.779724  2.998695  4.0 ...      3.0     i    ['i']  0.554341   1.0
# 923  722.262390  2.999565  4.0 ...     10.0     b    ['b']  0.446618   1.0
# 924  722.796875  3.000000  4.0 ...      5.0     v    ['v']  0.584496   1.0
#
#      subj  transition  trialNum  typing_raw walk
# 0       1       False       6.0           a  2.0
# 1       1       False       9.0           a  0.0
# 2       1       False      10.0           a  8.0
# 3       1       False      13.0           a  6.0
# 4       1       False      14.0           a  8.0
# 5       1       False      15.0           a  0.0
# 6       1       False      16.0           a  8.0
# 7       1       False      17.0           a  7.0
# 8       1       False      18.0           a  9.0
# 9       1       False      19.0           a  1.0
# 10      1       False      21.0           a  1.0
# 11      1       False      23.0           a  5.0
# 12      1        True      24.0           a  4.0
# 13      1       False      25.0           a  2.0
# 14      1       False      26.0           a  3.0
# 15      1       False      27.0           a  4.0
# 16      1       False      28.0           a  6.0
# 17      1       False      30.0           a  8.0
# 18      1       False      31.0           a  6.0
# 19      1       False      32.0           a  4.0
# 20      1       False      33.0           a  2.0
# 21      1       False      34.0           a  4.0
# 22      1       False      36.0           a  6.0
# 23      1       False      38.0           a  9.0
# 24      1       False      39.0           a  1.0
# 25      1       False      41.0           a  0.0
# 26      1        True      42.0           a  9.0
# 27      1       False      43.0           a  1.0
# 28      1       False      44.0           a  2.0
# 29      1       False      46.0           a  4.0
# ..    ...         ...       ...         ...  ...
# 895     4       False     969.0           a  4.0
# 896     4        True     970.0           a  5.0
# 897     4       False     971.0           a  8.0
# 898     4       False     972.0           a  7.0
# 899     4       False     974.0           a  8.0
# 900     4       False     975.0           a  9.0
# 901     4       False     976.0           a  6.0
# 902     4       False     977.0           a  8.0
# 903     4       False     978.0           a  5.0
# 904     4       False     979.0           a  6.0
# 905     4       False     980.0           a  7.0
# 906     4       False     981.0           a  5.0
# 907     4       False     982.0           a  8.0
# 908     4       False     983.0           a  7.0
# 909     4       False     984.0           a  6.0
# 910     4       False     985.0           a  7.0
# 911     4       False     986.0           a  6.0
# 912     4       False     987.0           a  7.0
# 913     4       False     988.0           a  9.0
# 914     4       False     989.0           a  8.0
# 915     4       False     990.0           a  9.0
# 916     4       False     991.0           a  7.0
# 917     4       False     992.0           a  9.0
# 918     4       False     993.0           a  7.0
# 919     4       False     994.0           a  5.0
# 920     4       False     995.0           a  6.0
# 921     4       False     996.0           a  7.0
# 922     4       False     997.0           a  5.0
# 923     4       False     999.0           a  8.0
# 924     4       False    1000.0           a  6.0
#
# [2727 rows x 21 columns]

# %%
data.to_csv("".join([save_dir, 'group_behavior']))
